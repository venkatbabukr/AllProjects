# %% [markdown]
# # **Notice Board**
#
# q4
#
# https://leetcode.com/problems/investments-in-2016/description/?lang=pythondata
#
# q3
#
# Write a solution to report the fraction of players that logged in again on the day after the day they first logged in, rounded to 2 decimal places. In other words, you need to count the number of players that logged in for at least two consecutive days starting from their first login date, then divide that number by the total number of players. The result format is in the following example.
#
# q2
#
# https://leetcode.com/problems/consecutive-numbers/?lang=pythondata
#
# q1ans
#
# ```python
# import pandas as pd
# def capital_gainloss(stocks) :
#   def akifa(i):
#     if i["operation"] == "Buy":
#       return -1 * i["price"]
#     else:
#       return i["price"]
#     stocks["capital_gain_loss"] = stocks.apply(lambda i : akifa(i), axis = 1) return stocks.groupby("stock_name")["capital_gain_loss"].sum().reset_index()
# ```
#
# q1
#
# https://leetcode.com/problems/capital-gainloss/?lang=pythondata
