# %% [markdown]
# $\newcommand{\trinom}[3]{\begin{pmatrix} #1 \\ #2 \\ #3 \end{pmatrix}}$

# %% [markdown]
# # **Q1. Confidence of Prediction**
#
# ![image.png](data:image/png;base64,...)
#
# The above diagram represents the scatterplot of data points that are of positive (green) or negative (red) class.
#
# There are four query points (orange) that are to be classified by the decision boundary (straight line) into one of the classes.
# Which of the query points will have the highest and lowest confidence of prediction respectively?
#
# **Note:** The probability that a data point belongs to the correct class is directly proportional to the distance of a point from the decision boundary
#
# **Options:**
#
# 1. A, C
# 2. D, C
# 3. A, B
# 4. A, D

# %% [markdown]
# #### **Ans:**
#
# Option 3: A, B
#
# **Confidence** of the prediction of **points which lie far away from the decision boundary** will be **more**.
#
# **Points lying near the decision boundary** will have **less confidence**, as there is chance that it belongs to the other class.
#
# **Probability** that a data point belongs to the correct class is **directly proportional** to **distance of point** from decision boundary
#
# A - lies farthest from the decision boundary,
# so it will have highest confidence of prediction
#
# B - lies closest to the decision boundary,
# so it will have lowest confidence of prediction

# %% [markdown]
# # **Q2. Plane distance**
#
# Find the distance of the point (−6, 0, 0) from the plane 2x - 3y + 6z = 2

# %% [markdown]
# #### **Ans**
#
# Distance of point = (2 * -6 - 3 * 0 + 6 * 0 -2) / $\sqrt{2^2 + (-3)^2 + 6^2}$
#
# = -14/$\sqrt{49}$
#
# = -14/7
#
# = -2

# %% [markdown]
# # **Q3. Decision function**
#
# Suppose you want to implement a decision function to classify the data points into two classes => {0, 1}.
#
# If the data point lies towards the normal then we can classify it as class 1, otherwise class 0.
#
# Which option correctly implements the given condition?
#
# Note: **x** represents the data point, **w** and **${w_0}$** represent the weights of the plane.
#
# **a.**
# ```python
# import numpy as np
# def classifyDataPoint(w, w0, x):
#   if np.dot(w, x) + w0 < 0:
#     return 1
#   else:
#     return 0
# ```
# **b.**
# ```python
# import numpy as np
# def classifyDataPoint(w, w0, x):
#   if np.dot(w, w0) + x > 0:
#     return 1
#   else:
#     return 0
# ```
# **c.**
# ```python
# import numpy as np
# def classifyDataPoint(w, w0, x):
#   if np.dot(w, x) + w0 > 0:
#     return 1
#   else:
#     return 0
# ```
# **d.**
# ```python
# import numpy as np
# def classifyDataPoint(w, w0, x):
#   if np.dot(w, w0) + x < 0:
#     return 1
#   else:
#     return 0
# ```

# %% [markdown]
# #### **Ans:**
#
# Option c.
# ```python
# import numpy as np
# def classifyDataPoint(w, w0, x):
#   if np.dot(w, x) + w0 > 0:
#     return 1
#   else:
#     return 0
# ```

# %% [markdown]
# # **Q4. Determine the Accuracy**
#
# Accuracy is one of the metrics used for classification problems.
#
# It is defined as: **Accuracy = (number of correctly classified points)/(total number of points)**.
#
# Given an equation of the separating plane as $3x_1 + 4x_2 + 1 = 0$, determine the accuracy of this plane on the given below dataset.
#
# <table>
#     <thead>
#         <tr>
#             <td>$x_1$</td>
#             <td>$x_2$</td>
#             <td>Label</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1</td>
#             <td>4</td>
#             <td>+ve</td>
#         </tr>
#         <tr>
#             <td>-2</td>
#             <td>-1</td>
#             <td>-ve</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td>-1</td>
#             <td>-ve</td>
#         </tr>
#     </tbody>
# </table>
#
# **Note:** Our model is designed in such a way that any point lying towards the normal will be classified as positive otherwise negative.

# %% [markdown]
# #### **Ans**
#
# Accuracy = 2/3 = 0.667. See table below:
#
# <table>
#     <thead>
#         <tr>
#             <td>x_1</td>
#             <td>x_2</td>
#             <td>Label</td>
#             <td>Point distance</td>
#             <td>Model classification</td>
#             <td>Correct classification (Yes/No)?</td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1</td>
#             <td>4</td>
#             <td>+ve</td>
#             <td> +4 (3 * 1 + 4 * 4 + 1) / 5<td>
#             <td>+ve</td>
#             <td>Yes</td>
#         </tr>
#         <tr>
#             <td>-2</td>
#             <td>-1</td>
#             <td>-ve</td>
#             <td> -9/5 (3 * -2 + 4 * -1 + 1) / 5<td>
#             <td>-ve</td>
#             <td>Yes</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td>-1</td>
#             <td>-ve</td>
#             <td> 6/5 (3 * 3 + 4 * -1 + 1) / 5<td>
#             <td>+ve</td>
#             <td>No</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # **Q5. Projection**
#
# Given vectors $v_1$ and $v_2$ of same dimensionality, then the length of the projection of $v_1$ on $v_2$ is?

# %% [markdown]
# #### **Ans:**
#
# Length of projection = $v_1 . v_2 $ / ||$v_2$||

# %% [markdown]
# # **Q6. Straight line or not**
#
# You are given a list of (X,Y) coordinates, check whether the coordinates lie on a straight line or not. If they lie on a straight line return the slope and intercept else return −1.

# %%
def slope(x1, y1, x2, y2):
    return (y2 - y1) / (x2 - x1) if x1 != x2 else 0

def yintercept(x, y, m):
  return y - m * x

def straight_line_or_not(coordinates):
    """
        Input is the list of tuples containg the coordiantes.
        Fucntion computes the slope and intercept if the points lies in a straight line.
        If lie straight line return the tuple (slope,intercept) having float values till one deciaml point.
        else, return -1
    """
    x1, y1 = coordinates[0]
    x2, y2 = coordinates[1]
    c12_slope = slope(x1, y1, x2, y2)
    for (x, y) in coordinates[2:]:
        cxy_slope = slope(x1, y1, x, y)
        if cxy_slope != c12_slope:
            return -1
    return (c12_slope, yintercept(x1, y1, c12_slope))

c = [(1.0, 5.0), (-3.0, -3.0), (2.5, 8.0)]
print(f"straight_line_or_not({c}) = {straight_line_or_not(c)}")
c = [(5.0, 5.0), (-2.0, -3.0), (0.0, 0.0), (14.0, 6.7), (-3.0, -6.3)]
print(f"straight_line_or_not({c}) = {straight_line_or_not(c)}")
# Out:
# straight_line_or_not([(1.0, 5.0), (-3.0, -3.0), (2.5, 8.0)]) = (2.0, 3.0)
# straight_line_or_not([(5.0, 5.0), (-2.0, -3.0), (0.0, 0.0), (14.0, 6.7), (-3.0, -6.3)]) = -1

# %% [markdown]
# # **AQ1. Equation of a plane**
#
# Given that we have a plane ax + by + c = 0 and a data point (x1, y1).
#
# Now when we insert this data point into the equation of a plane, we get ax1 + by1 + c > 0.
#
# What can be said about this data point?
#
# Options:
#
#
# 1. The datapoint (x1, y1) lies towards the normal of the plane
#
# 2. The datapoint (x1, y1) lies towards in opposite direction to the normal of the plane
#
# 3. The datapoint (x1, y1) lies on the plane
#
# 4. Nothing can be concluded

# %% [markdown]
# ####**Ans:**
#
# Option 1. The datapoint (x1, y1) lies towards the normal of the plane

# %% [markdown]
# # **AQ2. Two Planes**
#
# Given two equations of plane $\pi$1: 2x + 3y + 6 = 0 and $\pi$2: 4x + 6 + 12 = 0. How many common/intersecting points these planes have?

# %% [markdown]
# #### **Ans:**
#
# Infinite, because (m1, c1) = (-2/3, -3) same as (m2, c2) = (-4/6, -3)

# %% [markdown]
# # **AQ3. Colliding robots**
#
# Three robots have been programmed to move along the paths x - y - 2 = 0, x + y - 4 = 0, and x + 3y = 6 in an infinite space.
#
# Do you think that these robots will ever collide?

# %% [markdown]
# #### **Ans:**
#
# Yes.
#
# Solve for x & y from the two equations: x - y - 2 = 0 and x + y - 4 = 0, we get:
#
# x - y = 2
#
# x + y = 4
#
# => x = 3 and y = 1
#
# Substituting these values into the third equation x + 3y - 6, we get 3 + 3 * 1 - 6 = 0
#
# Hence, all three lines intersect at the point (3, 1)
