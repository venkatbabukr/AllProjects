# %%
10 + 3
# Out:
# 13

# %%
10 - 3
# Out:
# 7

# %%
10 * 3
# Out:
# 30

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10/2
# Out:
# 5.0

# %%
5.0 + 5 # float + float -> float
# Out:
# 10.0

# %%
5 ** 2
# Out:
# 25

# %%
5 ** -1
# Out:
# 0.2

# %%
1/5
# Out:
# 0.2

# %%
5 ** 0.5
# Out:
# 2.23606797749979

# %%
5.0 ** 2
# Out:
# 25.0

# %%
10//3
# Out:
# 3

# %%
-10//3 # floor divistion
# Out:
# -4

# %%
10 % 3 # modulus
# Out:
# 1

# %%
10 % 3.0
# Out:
# 1.0

# %%
-10//3.0
# Out:
# -4.0

# %%
10%-3
# Out:
# -2

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(50)
# Out:
# True

# %%
bool(-50)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool('False')
# Out:
# True

# %%
bool("  ")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
my_marks = 80
my_cousin_marks = 90
my_marks > my_cousin_marks
# Out:
# False

# %%
my_marks < my_cousin_marks
# Out:
# True

# %%
my_marks == my_cousin_marks
# Out:
# False

# %%
my_marks = 90
my_marks == my_cousin_marks # sql = is a comparison operator
# Out:
# True

# %%
my_marks != my_cousin_marks
# Out:
# False

# %%
my_marks <> my_cousin_marks # this not-equal to doesn't work in python
# Out:
#   File "<ipython-input-37-3f49f2ec0d0e>", line 1
#     my_marks <> my_cousin_marks
#              ^
# SyntaxError: invalid syntax

# %%
# Question - What will be the output?

marks = 50

marks = marks + correction

marks = marks + correction
marks
# Out:
# 51.0

# %%
# Question - What will be the output?

a = 5
a += 2 # a = a + 2
print(a) # 7
a -= 2
print(a) # 5
a *= 2
print(a) # 10
# Out:
# 7
# 5
# 10

# %%
# Question - What will be the output?

a=10
print(a>5 or a>20 or a<2) #True
print(a>5 and a==20 and a<2) #False
# Out:
# True
# False

# %%
# Question - Check if a number is a multiple?

amount = 1000
amount % 500 == 0
# Out:
# True

# %%
# ATM Dispatch for 2 kinds of denominations ( H.W to fix this piece of code)

amount= int(input("Please enter the amount to withdraw: "))
amount % 500 == 0 or amount % 200 == 0 # 900 = 500 + 200 + 200
# Out:
# Please enter the amount to withdraw: 900
# False

# %%
print(not True)

print(not False)

print(not 24 < 56)
# Out:
# False
# True
# False
