# %%
print(3000)
# Out:
# 3000

# %%
print(20+30)
# Out:
# 50

# %%
print(4  +    5)
# Out:
# 9

# %%
print("India won the world cup in 2024")
# Out:
# India won the world cup in 2024

# %%
print('India won the world cup in 2024')
# Out:
#   File "<ipython-input-7-aa660731b330>", line 1
#     print(India won the world cup in 2024)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
PRINT("will this work?") # python is case sensitive

# %%
print(4 < 3)
# Out:
# False

# %%
print("Hello class')

# %%
type(.2)
# Out:
# float

# %%
type(2.)
# Out:
# float

# %%
type(2)
# Out:
# int

# %%
type("2.4") # str ~ string
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
print(type(None))
type(1)
# Out:
# <class 'NoneType'>
# int

# %%
a = 3 + 4
print(a)
# Out:
# 7

# %%
b = 5
a + b
# Out:
# 12

# %%
a= 6
a + b
# Out:
# 11

# %%
x = 6
x= 5.2
print(x)
# Out:
# 5.2

# %%
x = " I am"
y = "Legend!"
print(x)
print(y)
# Out:
#  I am
# Legend!

# %%
print(x,y)
# Out:
#  I am Legend!

# %%
x = 10
X = 20
print(X,x)
# Out:
# 20 10

# %%
5_pulkit = 2
# Out:
#   File "<ipython-input-27-1bcd3278c009>", line 1
#     5_pulkit = 2
#      ^
# SyntaxError: invalid decimal literal

# %%
pulkit_5 = 2

# %%
pulkit5 = 4
# Out:
#   File "<ipython-input-29-0879fca396a7>", line 1
#     pulkit@5 = 4
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_pulkit = 10

# %%
_ = 10 # highly recommend not to use this

# %%
x = 10
y = x
print(y)
# Out:
# 10

# %%
x = 5
print(x)
print(y)
# Out:
# 5
# 10

# %%
name = input()
print("Hello",name)
# Out:
# Noel
# Hello Noel

# %%
x = 3
y = 'hello'
num = y
y = 5
print(num, y)
# Out:
# hello 5

# %% [markdown]
# Input function with numeric data

# %%
x = input()
y = input()
x + y # example of python's flexibility
# Out:
# 10
# 5
# '105'

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# type casting

# %%
x = input()
y = input()
int(x) + int(y) # example of python's flexibility
# Out:
# 10
# 5
# 15

# %%
x = float(input())
y = float(input())
x + y
# Out:
# 10
# 5
# 15.0

# %%
x = "this is a string"
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-7b24228a98ec> in <cell line: 2>()
#       1 x = "this is a string"
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: 'this is a string'

# %%
x = "10.5"
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-45dd87e97819> in <cell line: 2>()
#       1 x = "10.5"
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
x = 10
print(str(10))
# Out:
# 10

# %%
type(None)
# Out:
# NoneType

# %%
int(x) = input() # doubt from the class
# Out:
#   File "<ipython-input-46-2a382ef7ae5e>", line 1
#     int(x) = input()
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
