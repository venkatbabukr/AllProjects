# %%
import re # importing regex library

def is_vemail(s):
  email_pattern = "^\w+([\.-]?\w+)*@\w+([|.-]?\w+)*(\.\w{2,3})+$"
  res = re.search(email_pattern, s)
  # scans through string looking for the first location where pattern is found
  if res:
    return True
  else:
    return False

# %%
is_vemail("abcd@gmail")
# Out:
# False

# %%
is_vemail("abcd@xy.sx")
# Out:
# True

# %%
is_vemail("nikhil.sanghi@scaler-academy.co.in")
# Out:
# True

# %%
# !gdown 1sSDV5UspYZL3UUOGuiuxppSGcv1wS9ex
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1sSDV5UspYZL3UUOGuiuxppSGcv1wS9ex
# To: /content/data.txt
# 100% 9.33k/9.33k [00:00<00:00, 28.0MB/s]

# %%
data = open("data.txt", "r").read()
print(data[:500]) # display some data
# Out:
# Dave Martin
# 615-555-7164
# 173 Main St., Springfield RI 55924
# davemartin@bogusemail.com
#
# Charles Harris
# 800-555-5669
# 969 High St., Atlantis VA 34075
# charlesharris@bogusemail.com
#
# Eric Williams
# 560-555-5153
# 806 1st St., Faketown AK 86847
# laurawilliams@bogusemail.com
#
# Corey Jefferson
# 900-555-9340
# 826 Elm St., Epicburg NE 10671
# coreyjefferson@bogusemail.com
#
# Jennifer Martin-White
# 714-555-7405
# 212 Cedar St., Sunnydale CT 74983
# jenniferwhite@bogusemail.com
#
# Erick Davis
# 800-555-6771
# 519 Washington St.,

# %%
type(data)
# Out:
# str

# %%
pattern = "\d{3}-\d{3}-\d{4}"
print(re.match(pattern,data))
# Out:
# None

# %%
print(re.search(pattern,data))
# Out:
# <re.Match object; span=(12, 24), match='615-555-7164'>

# %%
data[12:24]
# Out:
# '615-555-7164'

# %%
phone_numbers = re.findall(pattern,data)
len(phone_numbers)
# Out:
# 100

# %%
print(re.finditer(pattern,data))
# Out:
# <callable_iterator object at 0x7a36c4293fd0>

# %% [markdown]
# general structure - (string1)@(string2).(2+characters)

# %%
email_pattern = "\w+@\w+\.[a-z]{2,3}"

# %%
emails = re.findall(email_pattern, data)
len(emails)
# Out:
# 100

# %%
name_pattern = "[A-Z][a-z]+\s[A-Z][a-z]+"

# %%
re.search(name_pattern, "Pulkit Aneja")

# %% [markdown]
# Quiz

# %%
re.match('ab?','abb')
# Out:
# <re.Match object; span=(0, 2), match='ab'>

# %%
x='[0-9]+'
re.findall(x, '7 apples and 4 mangoes')

# %%
# !wcurl
