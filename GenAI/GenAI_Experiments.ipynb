# %% [markdown]
# $\newcommand{\trinom}[3]{\begin{pmatrix} #1 \\ #2 \\ #3 \end{pmatrix}}$

# %% [markdown]
# # **Sample code to access Google Gemini and print results**

# %%
import os
from google import genai

# 1. Setup your API Key
# Get one for free at: https://aistudio.google.com/
os.environ["GOOGLE_API_KEY"] = "AIzaSyC8dhcRRxfGlYVOo9Mx4WpUDn1Stugf2WU"

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

def get_gemini_wine_recommendation(user_prompt):
    try:
        response = client.models.generate_content(
            model="gemini-3-flash-preview", # Latest fast and capable model
            config={
                "system_instruction": "You are a wine specialist. Your priority is to help users select amazing wine."
            },
            contents=user_prompt
        )
        return response.text
    except Exception as e:
        return f"An error occurred: {e}"

# Run the request
prompt = "Suggest me an amazing Malbec wine from Argentina"
print(get_gemini_wine_recommendation(prompt))
# Out:
# Argentina is the undisputed spiritual home of Malbec, and because the terroir varies so significantly from the high-altitude deserts of Salta to the icy tip of Patagonia, there isn't just one "amazing" Malbec—there are several styles.
#
# Here are four exceptional recommendations ranging from "iconic luxury" to "hidden gem."
#
# ### 1. The Benchmark of Luxury: Catena Zapata 'Adrianna Vineyard' River Stones
# If you want the absolute pinnacle of Argentine Malbec, this is it. The Catena family is largely responsible for putting Argentine wine on the map, and the Adrianna Vineyard in Gualtallary (Uco Valley) is considered the "Grand Cru" of South America.
# *   **The Vibe:** Elegance over power. Because it grows in an ancient stony riverbed at high altitude, it is incredibly mineral-driven.
# *   **Tasting Notes:** Expect high-toned aromas of violets, crushed stones, and bright red fruit rather than heavy oak. It has a "silky" texture that is world-class.
# ...

# %% [markdown]
# #RAG

# %% [markdown]
# ## **RAG samples by guyernest**
#
# Github link: https://github.com/guyernest/advanced-rag
